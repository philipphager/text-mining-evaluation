# %%
from gensim.models import AuthorTopicModel
import pandas as pd

# %%
model = AuthorTopicModel.load('./model/model.atm')

# %%
topics = []
for index, topic in enumerate(model.show_topics(num_topics=30, num_words=20)):
    topic_list = []
    for word, prob in model.show_topic(topic[0]):
        topic_list.append(word)
    topics.append(topic_list)

# %%
column_names = ['Topic ' + str(col + 1) for col in range(len(topics))]
df = pd.DataFrame(topics, index=column_names)
df = df

# %%
df.transpose()
# Out:
#      Topic 1 Topic 2  Topic 3   Topic 4  Topic 5       Topic 6     Topic 7  \
# 0        amp    time   people      good      dog        labour      school
# 1     school    good  country      jade    phone         party  university
# 2       area    year  british   company  library         union     student
# 3      world    like     like     smoke  realise           tax     teacher
# 4        art    come    world      card    house        public         job
# 5    theatre   great     live  research   norway  conservative   education
# 6       film    work   friend      book   fiddle          work       state
# 7     future     day  believe      anti   poster          vote      system
# 8       play  simply     find      read       hr    democratic       place
# 9  education    half      let       die      gym           cut      course
#
#       Topic 8       Topic 9    Topic 10      ...       Topic 21  Topic 22  \
# 0  government         think  restaurant      ...        excited      wine
# 1       issue          feel        food      ...         series     cheap
# 2       point          time          uk      ...           like      half
# 3      result  relationship       curry      ...          light   italian
# 4     measure        people       serve      ...        episode    travel
# 5     suggest          like       drink      ...            ask    madrid
# 6        case          need   different      ...          bring    decent
# 7         way          know      indian      ...            set     italy
# 8   political          work     pudding      ...           mean     seven
# 9    analysis          find       water      ...       remember  brighton
#
#   Topic 23 Topic 24 Topic 25 Topic 26    Topic 27 Topic 28    Topic 29  \
# 0    think     work    think     good        life   france         tax
# 1   people   people     good     like     product  english         pay
# 2    thing    child     know  jackson  personally   result        work
# 3     good     life     like     know       apple      god      people
# 4    right     year  article     film    previous    pinch  government
# 5    point     need    thing     want      desire      ago       money
# 6      way    woman     read      yes     usually   french       local
# 7     want     time    write      man    creative    heart        need
# 8  comment      way     love     book  understand    sorry      public
# 9   reason     want      man     look         lol  perfect        year
#
#        Topic 30
# 0          beer
# 1      scotland
# 2      scottish
# 3     australia
# 4          flag
# 5          shop
# 6           snp
# 7         drink
# 8             w
# 9  charity_shop
#
# [10 rows x 30 columns]

# %%
def print_author_topics(model, author_id):
    print(f'AuthorID: {author_id}')
    print(f'Num Docs: {len(model.author2doc[author_id])}')
    print(f'Docs: {model.author2doc[author_id]}')
    df = pd.DataFrame(model[author_id], columns=['Topic', 'Value'])
    df = df.sort_values(by='Value', ascending=False)
    print(df)

# %%
print_author_topics(model, '7083')
# Out:
# AuthorID: 7083
# Num Docs: 21
# Docs: [705, 2541, 2542, 4221, 4895, 6616, 7982, 8491, 9763, 14035, 14500, 14501, 14503, 14504, 15539, 16307, 16308, 16929, 16935, 16936, 17981]
#     Topic     Value
# 0       1  0.460414
# 6      29  0.113831
# 13     49  0.089854
# 1       3  0.061330
# 2       4  0.057731
# 11     41  0.046992
# 10     40  0.033180
# 5      24  0.030803
# 9      37  0.023997
# 3      11  0.020567
# 4      13  0.016553
# 8      36  0.013816
# 12     47  0.012908
# 7      35  0.011155

# %%
print_author_topics(model, '10607')
# Out:
# AuthorID: 10607
# Num Docs: 29
# Docs: [1223, 2520, 2532, 3044, 4387, 4388, 4553, 4853, 4865, 4866, 4870, 6602, 6603, 6604, 6605, 9738, 11392, 11394, 14509, 14510, 14511, 14512, 14513, 14516, 15542, 17443, 18224, 19213, 19214]
#     Topic     Value
# 9      29  0.226553
# 0       1  0.134738
# 1       2  0.086829
# 13     47  0.085344
# 12     45  0.072668
# 4      10  0.068642
# 8      28  0.067985
# 3       6  0.052782
# 11     41  0.049497
# 6      23  0.045592
# 10     36  0.028994
# 2       5  0.028114
# 7      24  0.019381
# 5      21  0.014081

# %%
df_comments = pd.read_csv('/Volumes/Samsung_T5/Documents/Uni/text_mining/part_users/converted_selected_sorted_comments-standardized.csv')

# %%
author_comments = model.author2doc['7083']

# %%
pd.set_option('display.max_colwidth', -1)
df_comments[df_comments['comment_id'].isin(author_comments)]['comment_text']
# Out:
# 705      Any substitute for gammon? Not sure they cure Pork that way where I am.
# 2541     My knowledge on limited overs Cricket would hardly be described as extensive but shouldn't England stick with this team?  For those that know more about Cricket would that be wise???
# 2542     Surely Carragher wlll go as fourth choice CB and not as reserve RB. For Capello to go out of his way to bring him back into the fold surely proves this. Otherwise, is Jamie Carragher really the 2nd best RB in the country?
# 4221     I dont think the young and the brave will be very happy.  As a student, all that was needed for the train and buses was an old travelcard and a carefully placed finger over the date!!!!
# 4895     'Oh, Oh, Oh, Oh, Oh, We've got the best midfield in the world, we've got Xabi Alonso, Momo Sissoko, Gerrard and Mascherano!' The triangulate of the current Liverpool side - Gerrard, Alonso, Mascherano - is undoubtedly the toughest central midfield in the world today. Although the Barcelona center with Iniesta and Xavi rivals it due to their superior technical ability, the Liverpool centre has the edge simply because of its shear toughness. Liverpool's status as the best team in European Football over the last 5 years is mainly due to this center and it has now replaced the Milan side of the 00's - Pirlo, Seedorf, Gattuso and Kaka - as the most dominant midfield in European club football today.
# 6616     OK! Well I guess i'll go it alone but does anyone ever blame top players for a defeat?  Is it always the manager or the token joke player?  Most criticise Benitez or Lucas but why are the others absolved of any blame?  Torres and Gerrard both missed very easy chances in the first half which surely would have affected the outcome of the game.  The 2nd half team last night was the same team as we've seen all season. It's the same team we saw at Anfield vs Chelsea in the Champions League last season. As a Liverpool fan, occasions that we go ahead and then wilt are few and far between. This season its happened way too much to be an isolated incident. Lyon, Fiorentina, Man City, Birmingham etc. All at Anfield.  I think it would be crazy to sack Rafa. He sets the team up perfectly to play the opposition. The games just mentioned its worked as they have always gone ahead. The problem is after getting a goal they look like they've passing a mine around the pitch.
# 16308    spain have won both the european championship and the world cup whilst barcelona have been dominant in the champions league but the history books cloud what actually happened.  spain were the clear favorites for the world cup last year, yet lost their opening game and did an 'arsenal' in the knockout stages by winning every game 1 nill. now im not saying they were lucky, just that they didn't play as well as what people are already 1 year later saying. In 20 years, people will say spain walked the world cup in south africa back in 2010. barcelona beat an average United team in the final of the champions league last season. But in the previous 2 seasons got outthought by both Hiddink and Mourinho. Yes they beat Chelsea but they really shouldn't have done.  the point im making is that this period in history, which will be one glorified as one that spain and barca dominated bar a few decisions or moments could have been very different.  i have nothing against spain or barca, but football evolves, teams will learn to play against them and their dominance will wane unless they evolve.  a tactical article jonathan on how to beat barcelona (because they are the stronger of the 2 teams mentioned) would be a far better read. suggested formations, personnel etc.  personally i'd like to see a team play 3 at the back against them, press them high up the pitch (they have little pace to get in behind) and stick 2 fast, strong players up top.
# 16929    Pointless list. How can you have a 6 of the best without the best??? Trevor Sinclair, where are you??? I believe it knocked David Beckham of the top spot for MOTD goal of the season!
# 16935    err Rob Smyth.....  Clarence Seedorf, think it was when he was at madrid, just belted one from near the halfway. not like a beckham lob, just belted and it screamed into the top corner!!
# 16936    I hope Capello is taken note. Forget counselling John Terry, Capello needs to start watching United so he can change the formation of his England team. After doubts that Rooney could lead a line on his own, it is now imperitive that he now does the same with England. It would allow Heskey to be dropped, Gerrard to move into his favoured postion just off Rooney, and free up the left midfield slot for hopefully an improving Joe Cole.  Surely Gerrard and Rooney up top is the way forward in South Africa. Anyone disagree?
# 17981    Give it to Benitez! He's obviously waiting around in England for something.  Great cup record. Suit England because he has done amazing things with pretty mediocre players.  Also the lack of an international transfer market is an added bonus!
# Name: comment_text, dtype: object

# %%
model.print_topic(21, topn=20)
# Out:
# '0.034*"labour" + 0.024*"party" + 0.020*"union" + 0.015*"tax" + 0.015*"public" + 0.014*"conservative" + 0.014*"work" + 0.013*"vote" + 0.012*"democratic" + 0.012*"cut" + 0.012*"worker" + 0.012*"left" + 0.011*"election" + 0.011*"care" + 0.010*"wing" + 0.009*"government" + 0.009*"hard" + 0.008*"cameron" + 0.008*"left_wing" + 0.008*"opposition"'

# %%
def print_topic_df(model, topic_id, topn=20):
    d = model.print_topic(topic_id, topn).replace('"', '').split('+')
    d = [el.split('*') for el in d]
    df = pd.DataFrame(d, columns=['prob', 'word'])
    return df

# %%
print_topic_df(model, 21)
# Out:
#       prob           word
# 0   0.034   labour
# 1    0.024  party
# 2    0.020  union
# 3    0.015  tax
# 4    0.015  public
# 5    0.014  conservative
# 6    0.014  work
# 7    0.013  vote
# 8    0.012  democratic
# 9    0.012  cut
# 10   0.012  worker
# 11   0.012  left
# 12   0.011  election
# 13   0.011  care
# 14   0.010  wing
# 15   0.009  government
# 16   0.009  hard
# 17   0.008  cameron
# 18   0.008  left_wing
# 19   0.008  opposition
